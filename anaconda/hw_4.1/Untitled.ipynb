# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from os import listdir
DATA_PATH = '/Users/husbook/Desktop/Data/'
listdir(DATA_PATH)
# Out:
# ['S2_04_004.dat',
#  'S2_04_005.dat',
#  'S2_04_001.dat',
#  'S2_04_002.dat',
#  'S2_04_003.dat',
#  'S2_03_005.dat',
#  'S2_03_004.dat',
#  'S2_02_001.dat',
#  'S2_02_003.dat',
#  'S2_02_002.dat',
#  'S2_03_003.dat',
#  'S2_03_002.dat',
#  'S2_03_001.dat',
#  'S2_01_003.dat',
#  'S2_01_002.dat',
#  'S2_01_001.dat',
#  'S2_01_005.dat',
#  'S2_01_004.dat']

# %%
x = np.random.randn(1000000)
a, b, _ = plt.hist(x, 1000)
plt.show()
plt.plot(b[1:], a)
plt.semilogy()
plt.show()

# %%
data = []
with open(f'{DATA_PATH}S2_01_001.dat') as f:
    for i in f:
        data.append(float(i.strip()))
pd.DataFrame(data).plot()

# %%
d = plt.hist(data, 50)
plt.semilogy()
# plt.semilogx()
plt.show()

# %%
a, b, c = d
plt.semilogy()
plt.plot(b[1:], a)

# %%
from math import sqrt
for file in range(1, 6):
    with open(f'{DATA_PATH}S2_01_00{file}.dat') as f:
        data = [float(i.strip()) for i in f]
    plt.subplot(3, 2, file)
    d = plt.hist(data, int(sqrt(len(data))/2))
plt.show()
